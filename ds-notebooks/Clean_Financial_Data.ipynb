# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gold = pd.read_csv("https://raw.githubusercontent.com/labs13-quake-viewer/ds-data/master/Gold%201968-present.csv")
gold.shape
# Out:
# (13350, 2)

# %%
gold.describe()
# Out:
#        closing_price
# count   13350.000000
# mean      526.193945
# std       434.811115
# min        34.750000
# 25%       276.300000
# 50%       379.850000
# 75%       643.687500
# max      1895.000000

# %%
(gold == 0).sum()
# Out:
# observation_date    0
# closing_price       0
# dtype: int64

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13350 entries, 0 to 13349
# Data columns (total 2 columns):
# observation_date    13350 non-null object
# closing_price       13350 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 208.7+ KB

# %%
gold.closing_price.isnull().sum()
# Out:
# 0

# %%
gold.head(12)
# Out:
#    observation_date  closing_price
# 0        1968-04-01          37.70
# 1        1968-04-02          37.30
# 2        1968-04-03          37.60
# 3        1968-04-04          36.95
# 4        1968-04-05          37.00
# 5        1968-04-08          37.05
# 6        1968-04-09          37.50
# 7        1968-04-10          37.70
# 8        1968-04-11          38.00
# 9        1968-04-12          38.00
# 10       1968-04-15          38.00
# 11       1968-04-16          38.00

# %%
gold = gold.interpolate()

# %%
# Create line plot - takes forever
#sns.relplot(x="observation_date", y="closing_price",
#            data=gold, kind="line")
# Out:
# Error in callback <function flush_figures at 0x7fb17db7f400> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     111         # ignore the tracking, just draw and close all figures
#     112         try:
# --> 113             return show(True)
#     114         except Exception as e:
#     115             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
# ...

# %%
gold.plot(x="observation_date", y="closing_price", figsize=(20, 10));

# %%
sp500 = pd.read_csv("https://raw.githubusercontent.com/labs13-quake-viewer/ds-data/master/S%26P%20500.csv")
sp500.shape
# Out:
# (17465, 2)

# %%
sp500.describe()
# Out:
#               Close
# count  17465.000000
# mean     581.980665
# std      695.673875
# min       16.660000
# 25%       86.070000
# 50%      167.470001
# 75%     1101.750000
# max     2945.830078

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17465 entries, 0 to 17464
# Data columns (total 2 columns):
# Date     17465 non-null object
# Close    17465 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 273.0+ KB

# %%
for i in range(3):
  j = (i + 1) * 6000
  shape = sp500.shape[0]
  if j > shape:
    j = shape
  sp500[i*6000:j-1].plot(x="Date", y="Close", figsize=(20, 10))

# %%
gold.to_csv("Gold 1968-present (cleaned).csv", index=False)
